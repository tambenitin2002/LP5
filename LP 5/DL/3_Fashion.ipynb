# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense,Flatten

# %%
# Load the Fashion MNIST dataset
(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 1s 20us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 291s 11us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 11s 3us/step

# %%
# Define label names
label_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Define the model
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(train_x, train_y, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 22s 12ms/step - loss: 3.2627 - accuracy: 0.6806 - val_loss: 0.8152 - val_accuracy: 0.7174
# Epoch 2/5
# 1500/1500 [==============================] - 18s 12ms/step - loss: 0.7119 - accuracy: 0.7226 - val_loss: 0.6813 - val_accuracy: 0.7318
# Epoch 3/5
# 1500/1500 [==============================] - 18s 12ms/step - loss: 0.6239 - accuracy: 0.7584 - val_loss: 0.6497 - val_accuracy: 0.7687
# Epoch 4/5
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.5731 - accuracy: 0.7983 - val_loss: 0.5725 - val_accuracy: 0.7936
# Epoch 5/5
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.5392 - accuracy: 0.8127 - val_loss: 0.5689 - val_accuracy: 0.8037

# %%
# Evaluate the model
loss, acc = model.evaluate(test_x, test_y)
print("Test Loss:", loss)
print("Test Accuracy:", acc)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5936 - accuracy: 0.8003
# Test Loss: 0.5935664176940918
# Test Accuracy: 0.8003000020980835

# %%
# Prediction function
def predict(id_):
    predictions = model.predict(test_x[id_:id_+1])
    label_index = np.argmax(predictions)
    label = label_names[label_index]
    print("Predicted Label:", label)
    plt.imshow(test_x[id_])
    plt.show()

# %%
# Example prediction
predict(5)
# Out:
# 1/1 [==============================] - 0s 218ms/step
# Predicted Label: Trouser

# %%
predict(6)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Predicted Label: Shirt

# %%
predict(1)
# Out:
# 1/1 [==============================] - 0s 54ms/step
# Predicted Label: Pullover
